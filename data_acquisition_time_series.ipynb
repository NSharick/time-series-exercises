# %% [markdown]
# #### Notebook for developing data acquisition functions contained in the .py file

# %%
import pandas as pd
import requests
from acquire import get_data
from acquire import get_opsd

# %%
url = 'https://api.data.codeup.com/documentation'
response = requests.get(url)
print(response.json()['payload'])
# Out:
# The API accepts GET requests for all endpoints, where endpoints are prefixed
# with
#
#     /api/{version}
#
# Where version is "v1"
#
# Valid endpoints:
#
# - /stores[/{store_id}]
# - /items[/{item_id}]
# - /sales[/{sale_id}]
#
# All endpoints accept a `page` parameter that can be used to navigate through
# the results.

# %%
url = 'https://api.data.codeup.com/api/v1/items'
response = requests.get(url)
data = response.json()
data.keys()
# Out:
# dict_keys(['payload', 'status'])

# %%
data['status']
# Out:
# 'ok'

# %%
data['payload'].keys()
# Out:
# dict_keys(['items', 'max_page', 'next_page', 'page', 'previous_page'])

# %%
data['payload']['next_page']

# %%
domain = 'https://api.data.codeup.com'
endpoint = '/api/v1/items'
items = []

url = domain + endpoint

response = requests.get(url)
data = response.json()
items.extend(data['payload']['items'])

# %%
data['payload']['next_page']
# Out:
# '/api/v1/items?page=2'

# %%
url = domain + data['payload']['next_page']
print('next url:', url)
# Out:
# next url: https://api.data.codeup.com/api/v1/items?page=2

# %%
response = requests.get(url)
data = response.json()
items.extend(data['payload']['items'])

# %%
url = domain + data['payload']['next_page']
print('next url:', url)
# Out:
# next url: https://api.data.codeup.com/api/v1/items?page=3

# %%
response = requests.get(url)
data = response.json()
items.extend(data['payload']['items'])

# %%
print('next endpoint', data['payload']['next_page'])
url = domain + data['payload']['next_page']
print('next url:', url)
# Out:
# next endpoint None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/n7/fjb2f8gd5jg17xlxz1c85vhc0000gn/T/ipykernel_39166/2661302222.py in <module>
#       1 print('next endpoint', data['payload']['next_page'])
# ----> 2 url = domain + data['payload']['next_page']
#       3 print('next url:', url)
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
domain = 'https://api.data.codeup.com'
endpoint = '/api/v1/items'
items = []
url = domain + endpoint
response = requests.get(url)
data = response.json()
items.extend(data['payload']['items'])
max_pages = (data['payload']['max_page'])+1
base_url = 'https://api.data.codeup.com/api/v1/items?page='
for page in range(2, max_pages):
    url = base_url + str(page)
    response = requests.get(url)
    data = response.json()
    items.extend(data['payload']['items'])
df = pd.DataFrame(items)

# %%
max_pages
# Out:
# 3

# %%
type(max_pages)
# Out:
# int

# %%
df
# Out:
#                 item_brand  item_id  \
# 0                 Riceland        1
# 1                   Caress        2
# 2              Earths Best        3
# 3               Boars Head        4
# 4           Back To Nature        5
# 5             Sally Hansen        6
# 6       Twinings Of London        7
# 7            Lea & Perrins        8
# 8             Van De Kamps        9
# 9                    Ahold       10
# 10              Honest Tea       11
# 11                 Mueller       12
# 12   Garnier Nutritioniste       13
# 13                 Pamprin       14
# 14                   Suave       15
# 15              Burts Bees       16
# 16                   Ducal       17
# 17                  Scotch       18
# 18                 Careone       19
# 19            Usda Produce       20
# 20            Doctors Best       21
# 21           Betty Crocker       22
# 22                   Reese       23
# 23            Smart Living       24
# 24                    Hood       25
# 25               Triaminic       26
# 26                  Morton       27
# 27            Usda Produce       28
# 28                   Heinz       29
# 29                 Petmate       30
# 30        Zhenas Gypsy Tea       31
# 31                Barefoot       32
# 32         The First Years       33
# 33                   Halls       34
# 34             Natures Way       35
# 35  Deerfields Gluten Free       36
# 36                  Nakano       37
# 37        Sundown Naturals       38
# 38                Munchies       39
# 39                    Amys       40
# 40             P.f. Changs       41
# 41      Moms Best Naturals       42
# 42                 Ferrara       43
# 43                  Elmers       44
# 44                Kelloggs       45
# 45              Mama Marys       46
# 46              Bear Naked       47
# 47                    Dove       48
# 48                Easy-off       49
# 49                  Choice       50
#
#                                             item_name  item_price  \
# 0                      Riceland American Jazmine Rice        0.84
# 1   Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2   Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 3    Boars Head Sliced White American Cheese - 120 Ct        3.14
# 4   Back To Nature Gluten Free White Cheddar Rice ...        2.61
# 5   Sally Hansen Nail Color Magnetic 903 Silver El...        6.93
# 6   Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 7   Lea & Perrins Marinade In-a-bag Cracked Pepper...        1.68
# 8          Van De Kamps Fillets Beer Battered - 10 Ct        1.79
# 9                                 Ahold Cocoa Almonds        3.17
# 10                         Honest Tea Peach White Tea        3.93
# 11  Mueller Sport Care Basic Support Level Medium ...        8.40
# 12  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 13  Pamprin Maximum Strength Multi-symptom Menstru...        7.54
# 14  Suave Naturals Moisturizing Body Wash Creamy T...        9.11
# 15      Burts Bees Daily Moisturizing Cream Sensitive        5.17
# 16                            Ducal Refried Red Beans        1.16
# 17    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 18                     Careone Family Comb Set - 8 Ct        0.74
# 19                                        Plums Black        5.62
# 20  Doctors Best Best Curcumin C3 Complex 1000mg T...        8.09
# 21  Betty Crocker Twin Pack Real Potatoes Scallope...        7.31
# 22     Reese Mandarin Oranges Segments In Light Syrup        1.78
# 23                Smart Living Charcoal Lighter Fluid        5.34
# 24         Hood Latte Iced Coffee Drink Vanilla Latte        2.43
# 25  Triaminic Syrup Night Time Cold & Cough Grape 4oz        0.98
# 26                          Morton Kosher Salt Coarse        6.01
# 27                                              Guava        7.52
# 28                        Heinz Tomato Ketchup - 2 Ct        8.65
# 29  Petmate Booda Bones Steak Bacon & Chicken Flav...        8.39
# 30  Zhenas Gypsy Tea Herbal Red Tea Sachets Fire L...        4.21
# 31                         Barefoot Pinot Grigio  187        0.68
# 32  Tomy The First Years Gumdrop Orthodontic Pacif...        6.52
# 33  Halls Menthol Cough Suppresant/oral Anesthetic...        4.17
# 34                     Natures Way Forskohlii - 60 Ct        5.19
# 35           Rice Bran Gluten Free Dinner Rolls Plain        7.95
# 36              Nakano Seasoned Rice Vinegar Original        9.59
# 37  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 38  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 39               Amys Light & Lean Spaghetti Italiano        0.60
# 40  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 41  Moms Best Naturals Cereal Toasted Cinnamon Squ...        2.97
# 42                              Ferrara Vanilla Syrup        8.40
# 43                Elmers Board Mate Dual Tip Glue Pen        7.06
# 44                Kelloggs Disney Pixar Cars 2 Cereal        4.40
# 45                                        Pizza Sauce        4.65
# 46  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# 47  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 48                  Easy-off Oven Cleaner Lemon Scent        9.54
# 49  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#       item_upc12    item_upc14
# 0    35200264013   35200264013
# 1    11111065925   11111065925
# 2    23923330139   23923330139
# 3   208528800007  208528800007
# 4   759283100036  759283100036
# 5    74170388732   74170388732
# 6    70177154004   70177154004
# 7    51600080015   51600080015
# 8    19600923015   19600923015
# 9   688267141676  688267141676
# 10  657622604842  657622604842
# 11   74676640211   74676640211
# 12  603084234561  603084234561
# 13   41167300121   41167300121
# 14   79400847201   79400847201
# 15  792850014008  792850014008
# 16   88313590791   88313590791
# 17   21200725340   21200725340
# 18   41520035646   41520035646
# 19  204040000000  204040000000
# 20  753950001954  753950001954
# 21   16000288829   16000288829
# 22   70670009658   70670009658
# 23  688267084225  688267084225
# 24   44100117428   44100117428
# 25  300436344045  300436344045
# 26   24600017008   24600017008
# 27  719175900007  719175900007
# 28   13000001038   13000001038
# 29  723503568678  723503568678
# 30  652790100226  652790100226
# 31    8500004528    8500004528
# 32   71463060078   71463060078
# 33  312546628694  312546628694
# 34   33674100066   33674100066
# 35  610358991525  610358991525
# 36   73575295003   73575295003
# 37   30768540548   30768540548
# 38   28400029254   28400029254
# 39   42272008063   42272008063
# 40   31000670016   31000670016
# 41  883978129115  883978129115
# 42   71403000379   71403000379
# 43   26000001403   26000001403
# 44   38000542237   38000542237
# 45   35457770664   35457770664
# 46  884623708976  884623708976
# 47   79400271631   79400271631
# 48   62338879772   62338879772
# 49   47445919221   47445919221

# %%
for x in range(2, max_pages):
    print(x)
# Out:
# 2

# %%
for x in range(2, 4):
    print(x)
# Out:
# 2
# 3

# %%
def get_data(domain, endpoint):
    items = []
    url = domain + endpoint
    response = requests.get(url)
    data = response.json()
    items.extend(data['payload']['items'])
    max_pages = (data['payload']['max_page'])+1
    base_url = 'https://api.data.codeup.com/api/v1/items?page='
    for page in range(2, max_pages):
        url = base_url + str(page)
        response = requests.get(url)
        data = response.json()
        items.extend(data['payload']['items'])
    df = pd.DataFrame(items)
    return df

# %%
df = get_data('https://api.data.codeup.com', '/api/v1/items')

# %%
df
# Out:
#                 item_brand  item_id  \
# 0                 Riceland        1
# 1                   Caress        2
# 2              Earths Best        3
# 3               Boars Head        4
# 4           Back To Nature        5
# 5             Sally Hansen        6
# 6       Twinings Of London        7
# 7            Lea & Perrins        8
# 8             Van De Kamps        9
# 9                    Ahold       10
# 10              Honest Tea       11
# 11                 Mueller       12
# 12   Garnier Nutritioniste       13
# 13                 Pamprin       14
# 14                   Suave       15
# 15              Burts Bees       16
# 16                   Ducal       17
# 17                  Scotch       18
# 18                 Careone       19
# 19            Usda Produce       20
# 20            Doctors Best       21
# 21           Betty Crocker       22
# 22                   Reese       23
# 23            Smart Living       24
# 24                    Hood       25
# 25               Triaminic       26
# 26                  Morton       27
# 27            Usda Produce       28
# 28                   Heinz       29
# 29                 Petmate       30
# 30        Zhenas Gypsy Tea       31
# 31                Barefoot       32
# 32         The First Years       33
# 33                   Halls       34
# 34             Natures Way       35
# 35  Deerfields Gluten Free       36
# 36                  Nakano       37
# 37        Sundown Naturals       38
# 38                Munchies       39
# 39                    Amys       40
# 40             P.f. Changs       41
# 41      Moms Best Naturals       42
# 42                 Ferrara       43
# 43                  Elmers       44
# 44                Kelloggs       45
# 45              Mama Marys       46
# 46              Bear Naked       47
# 47                    Dove       48
# 48                Easy-off       49
# 49                  Choice       50
#
#                                             item_name  item_price  \
# 0                      Riceland American Jazmine Rice        0.84
# 1   Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2   Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 3    Boars Head Sliced White American Cheese - 120 Ct        3.14
# 4   Back To Nature Gluten Free White Cheddar Rice ...        2.61
# 5   Sally Hansen Nail Color Magnetic 903 Silver El...        6.93
# 6   Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 7   Lea & Perrins Marinade In-a-bag Cracked Pepper...        1.68
# 8          Van De Kamps Fillets Beer Battered - 10 Ct        1.79
# 9                                 Ahold Cocoa Almonds        3.17
# 10                         Honest Tea Peach White Tea        3.93
# 11  Mueller Sport Care Basic Support Level Medium ...        8.40
# 12  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 13  Pamprin Maximum Strength Multi-symptom Menstru...        7.54
# 14  Suave Naturals Moisturizing Body Wash Creamy T...        9.11
# 15      Burts Bees Daily Moisturizing Cream Sensitive        5.17
# 16                            Ducal Refried Red Beans        1.16
# 17    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 18                     Careone Family Comb Set - 8 Ct        0.74
# 19                                        Plums Black        5.62
# 20  Doctors Best Best Curcumin C3 Complex 1000mg T...        8.09
# 21  Betty Crocker Twin Pack Real Potatoes Scallope...        7.31
# 22     Reese Mandarin Oranges Segments In Light Syrup        1.78
# 23                Smart Living Charcoal Lighter Fluid        5.34
# 24         Hood Latte Iced Coffee Drink Vanilla Latte        2.43
# 25  Triaminic Syrup Night Time Cold & Cough Grape 4oz        0.98
# 26                          Morton Kosher Salt Coarse        6.01
# 27                                              Guava        7.52
# 28                        Heinz Tomato Ketchup - 2 Ct        8.65
# 29  Petmate Booda Bones Steak Bacon & Chicken Flav...        8.39
# 30  Zhenas Gypsy Tea Herbal Red Tea Sachets Fire L...        4.21
# 31                         Barefoot Pinot Grigio  187        0.68
# 32  Tomy The First Years Gumdrop Orthodontic Pacif...        6.52
# 33  Halls Menthol Cough Suppresant/oral Anesthetic...        4.17
# 34                     Natures Way Forskohlii - 60 Ct        5.19
# 35           Rice Bran Gluten Free Dinner Rolls Plain        7.95
# 36              Nakano Seasoned Rice Vinegar Original        9.59
# 37  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 38  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 39               Amys Light & Lean Spaghetti Italiano        0.60
# 40  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 41  Moms Best Naturals Cereal Toasted Cinnamon Squ...        2.97
# 42                              Ferrara Vanilla Syrup        8.40
# 43                Elmers Board Mate Dual Tip Glue Pen        7.06
# 44                Kelloggs Disney Pixar Cars 2 Cereal        4.40
# 45                                        Pizza Sauce        4.65
# 46  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# 47  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 48                  Easy-off Oven Cleaner Lemon Scent        9.54
# 49  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#       item_upc12    item_upc14
# 0    35200264013   35200264013
# 1    11111065925   11111065925
# 2    23923330139   23923330139
# 3   208528800007  208528800007
# 4   759283100036  759283100036
# 5    74170388732   74170388732
# 6    70177154004   70177154004
# 7    51600080015   51600080015
# 8    19600923015   19600923015
# 9   688267141676  688267141676
# 10  657622604842  657622604842
# 11   74676640211   74676640211
# 12  603084234561  603084234561
# 13   41167300121   41167300121
# 14   79400847201   79400847201
# 15  792850014008  792850014008
# 16   88313590791   88313590791
# 17   21200725340   21200725340
# 18   41520035646   41520035646
# 19  204040000000  204040000000
# 20  753950001954  753950001954
# 21   16000288829   16000288829
# 22   70670009658   70670009658
# 23  688267084225  688267084225
# 24   44100117428   44100117428
# 25  300436344045  300436344045
# 26   24600017008   24600017008
# 27  719175900007  719175900007
# 28   13000001038   13000001038
# 29  723503568678  723503568678
# 30  652790100226  652790100226
# 31    8500004528    8500004528
# 32   71463060078   71463060078
# 33  312546628694  312546628694
# 34   33674100066   33674100066
# 35  610358991525  610358991525
# 36   73575295003   73575295003
# 37   30768540548   30768540548
# 38   28400029254   28400029254
# 39   42272008063   42272008063
# 40   31000670016   31000670016
# 41  883978129115  883978129115
# 42   71403000379   71403000379
# 43   26000001403   26000001403
# 44   38000542237   38000542237
# 45   35457770664   35457770664
# 46  884623708976  884623708976
# 47   79400271631   79400271631
# 48   62338879772   62338879772
# 49   47445919221   47445919221

# %%
def get_data(domain, endpoint, query_str, top_key, section_key, maxpage_key):
    items = []
    url = domain + endpoint
    response = requests.get(url)
    data = response.json()
    items.extend(data[top_key][section_key])
    max_pages = (data[top_key][maxpage_key])+1
    for page in range(2, max_pages):
        url = domain + endpoint + query_str + str(page)
        response = requests.get(url)
        data = response.json()
        items.extend(data[top_key][section_key])
    df = pd.DataFrame(items)
    return df

# %%
df = get_data('https://api.data.codeup.com', '/api/v1/items', '?page=', 'payload', 'items', 'max_page')
df
# Out:
#                 item_brand  item_id  \
# 0                 Riceland        1
# 1                   Caress        2
# 2              Earths Best        3
# 3               Boars Head        4
# 4           Back To Nature        5
# 5             Sally Hansen        6
# 6       Twinings Of London        7
# 7            Lea & Perrins        8
# 8             Van De Kamps        9
# 9                    Ahold       10
# 10              Honest Tea       11
# 11                 Mueller       12
# 12   Garnier Nutritioniste       13
# 13                 Pamprin       14
# 14                   Suave       15
# 15              Burts Bees       16
# 16                   Ducal       17
# 17                  Scotch       18
# 18                 Careone       19
# 19            Usda Produce       20
# 20            Doctors Best       21
# 21           Betty Crocker       22
# 22                   Reese       23
# 23            Smart Living       24
# 24                    Hood       25
# 25               Triaminic       26
# 26                  Morton       27
# 27            Usda Produce       28
# 28                   Heinz       29
# 29                 Petmate       30
# 30        Zhenas Gypsy Tea       31
# 31                Barefoot       32
# 32         The First Years       33
# 33                   Halls       34
# 34             Natures Way       35
# 35  Deerfields Gluten Free       36
# 36                  Nakano       37
# 37        Sundown Naturals       38
# 38                Munchies       39
# 39                    Amys       40
# 40             P.f. Changs       41
# 41      Moms Best Naturals       42
# 42                 Ferrara       43
# 43                  Elmers       44
# 44                Kelloggs       45
# 45              Mama Marys       46
# 46              Bear Naked       47
# 47                    Dove       48
# 48                Easy-off       49
# 49                  Choice       50
#
#                                             item_name  item_price  \
# 0                      Riceland American Jazmine Rice        0.84
# 1   Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2   Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 3    Boars Head Sliced White American Cheese - 120 Ct        3.14
# 4   Back To Nature Gluten Free White Cheddar Rice ...        2.61
# 5   Sally Hansen Nail Color Magnetic 903 Silver El...        6.93
# 6   Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 7   Lea & Perrins Marinade In-a-bag Cracked Pepper...        1.68
# 8          Van De Kamps Fillets Beer Battered - 10 Ct        1.79
# 9                                 Ahold Cocoa Almonds        3.17
# 10                         Honest Tea Peach White Tea        3.93
# 11  Mueller Sport Care Basic Support Level Medium ...        8.40
# 12  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 13  Pamprin Maximum Strength Multi-symptom Menstru...        7.54
# 14  Suave Naturals Moisturizing Body Wash Creamy T...        9.11
# 15      Burts Bees Daily Moisturizing Cream Sensitive        5.17
# 16                            Ducal Refried Red Beans        1.16
# 17    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 18                     Careone Family Comb Set - 8 Ct        0.74
# 19                                        Plums Black        5.62
# 20  Doctors Best Best Curcumin C3 Complex 1000mg T...        8.09
# 21  Betty Crocker Twin Pack Real Potatoes Scallope...        7.31
# 22     Reese Mandarin Oranges Segments In Light Syrup        1.78
# 23                Smart Living Charcoal Lighter Fluid        5.34
# 24         Hood Latte Iced Coffee Drink Vanilla Latte        2.43
# 25  Triaminic Syrup Night Time Cold & Cough Grape 4oz        0.98
# 26                          Morton Kosher Salt Coarse        6.01
# 27                                              Guava        7.52
# 28                        Heinz Tomato Ketchup - 2 Ct        8.65
# 29  Petmate Booda Bones Steak Bacon & Chicken Flav...        8.39
# 30  Zhenas Gypsy Tea Herbal Red Tea Sachets Fire L...        4.21
# 31                         Barefoot Pinot Grigio  187        0.68
# 32  Tomy The First Years Gumdrop Orthodontic Pacif...        6.52
# 33  Halls Menthol Cough Suppresant/oral Anesthetic...        4.17
# 34                     Natures Way Forskohlii - 60 Ct        5.19
# 35           Rice Bran Gluten Free Dinner Rolls Plain        7.95
# 36              Nakano Seasoned Rice Vinegar Original        9.59
# 37  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 38  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 39               Amys Light & Lean Spaghetti Italiano        0.60
# 40  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 41  Moms Best Naturals Cereal Toasted Cinnamon Squ...        2.97
# 42                              Ferrara Vanilla Syrup        8.40
# 43                Elmers Board Mate Dual Tip Glue Pen        7.06
# 44                Kelloggs Disney Pixar Cars 2 Cereal        4.40
# 45                                        Pizza Sauce        4.65
# 46  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# 47  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 48                  Easy-off Oven Cleaner Lemon Scent        9.54
# 49  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#       item_upc12    item_upc14
# 0    35200264013   35200264013
# 1    11111065925   11111065925
# 2    23923330139   23923330139
# 3   208528800007  208528800007
# 4   759283100036  759283100036
# 5    74170388732   74170388732
# 6    70177154004   70177154004
# 7    51600080015   51600080015
# 8    19600923015   19600923015
# 9   688267141676  688267141676
# 10  657622604842  657622604842
# 11   74676640211   74676640211
# 12  603084234561  603084234561
# 13   41167300121   41167300121
# 14   79400847201   79400847201
# 15  792850014008  792850014008
# 16   88313590791   88313590791
# 17   21200725340   21200725340
# 18   41520035646   41520035646
# 19  204040000000  204040000000
# 20  753950001954  753950001954
# 21   16000288829   16000288829
# 22   70670009658   70670009658
# 23  688267084225  688267084225
# 24   44100117428   44100117428
# 25  300436344045  300436344045
# 26   24600017008   24600017008
# 27  719175900007  719175900007
# 28   13000001038   13000001038
# 29  723503568678  723503568678
# 30  652790100226  652790100226
# 31    8500004528    8500004528
# 32   71463060078   71463060078
# 33  312546628694  312546628694
# 34   33674100066   33674100066
# 35  610358991525  610358991525
# 36   73575295003   73575295003
# 37   30768540548   30768540548
# 38   28400029254   28400029254
# 39   42272008063   42272008063
# 40   31000670016   31000670016
# 41  883978129115  883978129115
# 42   71403000379   71403000379
# 43   26000001403   26000001403
# 44   38000542237   38000542237
# 45   35457770664   35457770664
# 46  884623708976  884623708976
# 47   79400271631   79400271631
# 48   62338879772   62338879772
# 49   47445919221   47445919221

# %%
from acquire import get_data

# %%
df = get_data('https://api.data.codeup.com', '/api/v1/items', '?page=', 'payload', 'items', 'max_page')
df
# Out:
# https://api.data.codeup.com/api/v1/items?page=2
# https://api.data.codeup.com/api/v1/items?page=3
#                 item_brand  item_id  \
# 0                 Riceland        1
# 1                   Caress        2
# 2              Earths Best        3
# 3               Boars Head        4
# 4           Back To Nature        5
# 5             Sally Hansen        6
# 6       Twinings Of London        7
# 7            Lea & Perrins        8
# 8             Van De Kamps        9
# 9                    Ahold       10
# 10              Honest Tea       11
# 11                 Mueller       12
# 12   Garnier Nutritioniste       13
# 13                 Pamprin       14
# 14                   Suave       15
# 15              Burts Bees       16
# 16                   Ducal       17
# 17                  Scotch       18
# 18                 Careone       19
# 19            Usda Produce       20
# 20            Doctors Best       21
# 21           Betty Crocker       22
# 22                   Reese       23
# 23            Smart Living       24
# 24                    Hood       25
# 25               Triaminic       26
# 26                  Morton       27
# 27            Usda Produce       28
# 28                   Heinz       29
# 29                 Petmate       30
# 30        Zhenas Gypsy Tea       31
# 31                Barefoot       32
# 32         The First Years       33
# 33                   Halls       34
# 34             Natures Way       35
# 35  Deerfields Gluten Free       36
# 36                  Nakano       37
# 37        Sundown Naturals       38
# 38                Munchies       39
# 39                    Amys       40
# 40             P.f. Changs       41
# 41      Moms Best Naturals       42
# 42                 Ferrara       43
# 43                  Elmers       44
# 44                Kelloggs       45
# 45              Mama Marys       46
# 46              Bear Naked       47
# 47                    Dove       48
# 48                Easy-off       49
# 49                  Choice       50
#
#                                             item_name  item_price  \
# 0                      Riceland American Jazmine Rice        0.84
# 1   Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2   Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 3    Boars Head Sliced White American Cheese - 120 Ct        3.14
# 4   Back To Nature Gluten Free White Cheddar Rice ...        2.61
# 5   Sally Hansen Nail Color Magnetic 903 Silver El...        6.93
# 6   Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 7   Lea & Perrins Marinade In-a-bag Cracked Pepper...        1.68
# 8          Van De Kamps Fillets Beer Battered - 10 Ct        1.79
# 9                                 Ahold Cocoa Almonds        3.17
# 10                         Honest Tea Peach White Tea        3.93
# 11  Mueller Sport Care Basic Support Level Medium ...        8.40
# 12  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 13  Pamprin Maximum Strength Multi-symptom Menstru...        7.54
# 14  Suave Naturals Moisturizing Body Wash Creamy T...        9.11
# 15      Burts Bees Daily Moisturizing Cream Sensitive        5.17
# 16                            Ducal Refried Red Beans        1.16
# 17    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 18                     Careone Family Comb Set - 8 Ct        0.74
# 19                                        Plums Black        5.62
# 20  Doctors Best Best Curcumin C3 Complex 1000mg T...        8.09
# 21  Betty Crocker Twin Pack Real Potatoes Scallope...        7.31
# 22     Reese Mandarin Oranges Segments In Light Syrup        1.78
# 23                Smart Living Charcoal Lighter Fluid        5.34
# 24         Hood Latte Iced Coffee Drink Vanilla Latte        2.43
# 25  Triaminic Syrup Night Time Cold & Cough Grape 4oz        0.98
# 26                          Morton Kosher Salt Coarse        6.01
# 27                                              Guava        7.52
# 28                        Heinz Tomato Ketchup - 2 Ct        8.65
# 29  Petmate Booda Bones Steak Bacon & Chicken Flav...        8.39
# 30  Zhenas Gypsy Tea Herbal Red Tea Sachets Fire L...        4.21
# 31                         Barefoot Pinot Grigio  187        0.68
# 32  Tomy The First Years Gumdrop Orthodontic Pacif...        6.52
# 33  Halls Menthol Cough Suppresant/oral Anesthetic...        4.17
# 34                     Natures Way Forskohlii - 60 Ct        5.19
# 35           Rice Bran Gluten Free Dinner Rolls Plain        7.95
# 36              Nakano Seasoned Rice Vinegar Original        9.59
# 37  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 38  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 39               Amys Light & Lean Spaghetti Italiano        0.60
# 40  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 41  Moms Best Naturals Cereal Toasted Cinnamon Squ...        2.97
# 42                              Ferrara Vanilla Syrup        8.40
# 43                Elmers Board Mate Dual Tip Glue Pen        7.06
# 44                Kelloggs Disney Pixar Cars 2 Cereal        4.40
# 45                                        Pizza Sauce        4.65
# 46  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# 47  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 48                  Easy-off Oven Cleaner Lemon Scent        9.54
# 49  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#       item_upc12    item_upc14
# 0    35200264013   35200264013
# 1    11111065925   11111065925
# 2    23923330139   23923330139
# 3   208528800007  208528800007
# 4   759283100036  759283100036
# 5    74170388732   74170388732
# 6    70177154004   70177154004
# 7    51600080015   51600080015
# 8    19600923015   19600923015
# 9   688267141676  688267141676
# 10  657622604842  657622604842
# 11   74676640211   74676640211
# 12  603084234561  603084234561
# 13   41167300121   41167300121
# 14   79400847201   79400847201
# 15  792850014008  792850014008
# 16   88313590791   88313590791
# 17   21200725340   21200725340
# 18   41520035646   41520035646
# 19  204040000000  204040000000
# 20  753950001954  753950001954
# 21   16000288829   16000288829
# 22   70670009658   70670009658
# 23  688267084225  688267084225
# 24   44100117428   44100117428
# 25  300436344045  300436344045
# 26   24600017008   24600017008
# 27  719175900007  719175900007
# 28   13000001038   13000001038
# 29  723503568678  723503568678
# 30  652790100226  652790100226
# 31    8500004528    8500004528
# 32   71463060078   71463060078
# 33  312546628694  312546628694
# 34   33674100066   33674100066
# 35  610358991525  610358991525
# 36   73575295003   73575295003
# 37   30768540548   30768540548
# 38   28400029254   28400029254
# 39   42272008063   42272008063
# 40   31000670016   31000670016
# 41  883978129115  883978129115
# 42   71403000379   71403000379
# 43   26000001403   26000001403
# 44   38000542237   38000542237
# 45   35457770664   35457770664
# 46  884623708976  884623708976
# 47   79400271631   79400271631
# 48   62338879772   62338879772
# 49   47445919221   47445919221

# %%
url = 'https://api.data.codeup.com/api/v1/stores'
response = requests.get(url)
data = response.json()
data.keys()
# Out:
# dict_keys(['payload', 'status'])

# %%
data['payload'].keys()
# Out:
# dict_keys(['max_page', 'next_page', 'page', 'previous_page', 'stores'])

# %%
data['payload']['max_page']
# Out:
# 1

# %%
data['payload']['page']
# Out:
# 1

# %%
df = get_data('https://api.data.codeup.com', '/api/v1/stores', '?page=', 'payload', 'stores', 'max_page')
df
# Out:
#              store_address   store_city  store_id store_state store_zipcode
# 0   12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 1         9255 FM 471 West  San Antonio         2          TX         78251
# 2  2118 Fredericksburg Rdj  San Antonio         3          TX         78201
# 3          516 S Flores St  San Antonio         4          TX         78204
# 4          1520 Austin Hwy  San Antonio         5          TX         78218
# 5       1015 S WW White Rd  San Antonio         6          TX         78220
# 6   12018 Perrin Beitel Rd  San Antonio         7          TX         78217
# 7      15000 San Pedro Ave  San Antonio         8          TX         78232
# 8       735 SW Military Dr  San Antonio         9          TX         78221
# 9     8503 NW Military Hwy  San Antonio        10          TX         78231

# %%
url = 'https://api.data.codeup.com/api/v1/sales'
response = requests.get(url)
data = response.json()
data.keys()
# Out:
# dict_keys(['payload', 'status'])

# %%
data['payload'].keys()
# Out:
# dict_keys(['max_page', 'next_page', 'page', 'previous_page', 'sales'])

# %%
data['payload']['max_page']
# Out:
# 183

# %%
data['payload']['next_page']
# Out:
# '/api/v1/sales?page=2'

# %%
df = get_data('https://api.data.codeup.com', '/api/v1/sales', '?page=', 'payload', 'sales', 'max_page')
df
# Out:
# https://api.data.codeup.com/api/v1/sales?page=2
# https://api.data.codeup.com/api/v1/sales?page=3
# https://api.data.codeup.com/api/v1/sales?page=4
# https://api.data.codeup.com/api/v1/sales?page=5
# https://api.data.codeup.com/api/v1/sales?page=6
# https://api.data.codeup.com/api/v1/sales?page=7
# https://api.data.codeup.com/api/v1/sales?page=8
# https://api.data.codeup.com/api/v1/sales?page=9
# https://api.data.codeup.com/api/v1/sales?page=10
# https://api.data.codeup.com/api/v1/sales?page=11
# https://api.data.codeup.com/api/v1/sales?page=12
# https://api.data.codeup.com/api/v1/sales?page=13
# https://api.data.codeup.com/api/v1/sales?page=14
# https://api.data.codeup.com/api/v1/sales?page=15
# https://api.data.codeup.com/api/v1/sales?page=16
# https://api.data.codeup.com/api/v1/sales?page=17
# https://api.data.codeup.com/api/v1/sales?page=18
# https://api.data.codeup.com/api/v1/sales?page=19
# https://api.data.codeup.com/api/v1/sales?page=20
# https://api.data.codeup.com/api/v1/sales?page=21
# https://api.data.codeup.com/api/v1/sales?page=22
# https://api.data.codeup.com/api/v1/sales?page=23
# https://api.data.codeup.com/api/v1/sales?page=24
# https://api.data.codeup.com/api/v1/sales?page=25
# https://api.data.codeup.com/api/v1/sales?page=26
# https://api.data.codeup.com/api/v1/sales?page=27
# https://api.data.codeup.com/api/v1/sales?page=28
# https://api.data.codeup.com/api/v1/sales?page=29
# https://api.data.codeup.com/api/v1/sales?page=30
# https://api.data.codeup.com/api/v1/sales?page=31
# https://api.data.codeup.com/api/v1/sales?page=32
# https://api.data.codeup.com/api/v1/sales?page=33
# https://api.data.codeup.com/api/v1/sales?page=34
# https://api.data.codeup.com/api/v1/sales?page=35
# https://api.data.codeup.com/api/v1/sales?page=36
# https://api.data.codeup.com/api/v1/sales?page=37
# https://api.data.codeup.com/api/v1/sales?page=38
# https://api.data.codeup.com/api/v1/sales?page=39
# https://api.data.codeup.com/api/v1/sales?page=40
# https://api.data.codeup.com/api/v1/sales?page=41
# https://api.data.codeup.com/api/v1/sales?page=42
# https://api.data.codeup.com/api/v1/sales?page=43
# https://api.data.codeup.com/api/v1/sales?page=44
# https://api.data.codeup.com/api/v1/sales?page=45
# https://api.data.codeup.com/api/v1/sales?page=46
# https://api.data.codeup.com/api/v1/sales?page=47
# https://api.data.codeup.com/api/v1/sales?page=48
# https://api.data.codeup.com/api/v1/sales?page=49
# https://api.data.codeup.com/api/v1/sales?page=50
# https://api.data.codeup.com/api/v1/sales?page=51
# https://api.data.codeup.com/api/v1/sales?page=52
# https://api.data.codeup.com/api/v1/sales?page=53
# https://api.data.codeup.com/api/v1/sales?page=54
# https://api.data.codeup.com/api/v1/sales?page=55
# https://api.data.codeup.com/api/v1/sales?page=56
# https://api.data.codeup.com/api/v1/sales?page=57
# https://api.data.codeup.com/api/v1/sales?page=58
# https://api.data.codeup.com/api/v1/sales?page=59
# https://api.data.codeup.com/api/v1/sales?page=60
# https://api.data.codeup.com/api/v1/sales?page=61
# https://api.data.codeup.com/api/v1/sales?page=62
# https://api.data.codeup.com/api/v1/sales?page=63
# https://api.data.codeup.com/api/v1/sales?page=64
# https://api.data.codeup.com/api/v1/sales?page=65
# https://api.data.codeup.com/api/v1/sales?page=66
# https://api.data.codeup.com/api/v1/sales?page=67
# https://api.data.codeup.com/api/v1/sales?page=68
# https://api.data.codeup.com/api/v1/sales?page=69
# https://api.data.codeup.com/api/v1/sales?page=70
# https://api.data.codeup.com/api/v1/sales?page=71
# https://api.data.codeup.com/api/v1/sales?page=72
# https://api.data.codeup.com/api/v1/sales?page=73
# https://api.data.codeup.com/api/v1/sales?page=74
# https://api.data.codeup.com/api/v1/sales?page=75
# https://api.data.codeup.com/api/v1/sales?page=76
# https://api.data.codeup.com/api/v1/sales?page=77
# https://api.data.codeup.com/api/v1/sales?page=78
# https://api.data.codeup.com/api/v1/sales?page=79
# https://api.data.codeup.com/api/v1/sales?page=80
# https://api.data.codeup.com/api/v1/sales?page=81
# https://api.data.codeup.com/api/v1/sales?page=82
# https://api.data.codeup.com/api/v1/sales?page=83
# https://api.data.codeup.com/api/v1/sales?page=84
# https://api.data.codeup.com/api/v1/sales?page=85
# https://api.data.codeup.com/api/v1/sales?page=86
# https://api.data.codeup.com/api/v1/sales?page=87
# https://api.data.codeup.com/api/v1/sales?page=88
# https://api.data.codeup.com/api/v1/sales?page=89
# https://api.data.codeup.com/api/v1/sales?page=90
# https://api.data.codeup.com/api/v1/sales?page=91
# https://api.data.codeup.com/api/v1/sales?page=92
# https://api.data.codeup.com/api/v1/sales?page=93
# https://api.data.codeup.com/api/v1/sales?page=94
# https://api.data.codeup.com/api/v1/sales?page=95
# https://api.data.codeup.com/api/v1/sales?page=96
# https://api.data.codeup.com/api/v1/sales?page=97
# https://api.data.codeup.com/api/v1/sales?page=98
# https://api.data.codeup.com/api/v1/sales?page=99
# https://api.data.codeup.com/api/v1/sales?page=100
# https://api.data.codeup.com/api/v1/sales?page=101
# https://api.data.codeup.com/api/v1/sales?page=102
# https://api.data.codeup.com/api/v1/sales?page=103
# https://api.data.codeup.com/api/v1/sales?page=104
# https://api.data.codeup.com/api/v1/sales?page=105
# https://api.data.codeup.com/api/v1/sales?page=106
# https://api.data.codeup.com/api/v1/sales?page=107
# https://api.data.codeup.com/api/v1/sales?page=108
# https://api.data.codeup.com/api/v1/sales?page=109
# https://api.data.codeup.com/api/v1/sales?page=110
# https://api.data.codeup.com/api/v1/sales?page=111
# https://api.data.codeup.com/api/v1/sales?page=112
# https://api.data.codeup.com/api/v1/sales?page=113
# https://api.data.codeup.com/api/v1/sales?page=114
# https://api.data.codeup.com/api/v1/sales?page=115
# https://api.data.codeup.com/api/v1/sales?page=116
# https://api.data.codeup.com/api/v1/sales?page=117
# https://api.data.codeup.com/api/v1/sales?page=118
# https://api.data.codeup.com/api/v1/sales?page=119
# https://api.data.codeup.com/api/v1/sales?page=120
# https://api.data.codeup.com/api/v1/sales?page=121
# https://api.data.codeup.com/api/v1/sales?page=122
# https://api.data.codeup.com/api/v1/sales?page=123
# https://api.data.codeup.com/api/v1/sales?page=124
# https://api.data.codeup.com/api/v1/sales?page=125
# https://api.data.codeup.com/api/v1/sales?page=126
# https://api.data.codeup.com/api/v1/sales?page=127
# https://api.data.codeup.com/api/v1/sales?page=128
# https://api.data.codeup.com/api/v1/sales?page=129
# https://api.data.codeup.com/api/v1/sales?page=130
# https://api.data.codeup.com/api/v1/sales?page=131
# https://api.data.codeup.com/api/v1/sales?page=132
# https://api.data.codeup.com/api/v1/sales?page=133
# https://api.data.codeup.com/api/v1/sales?page=134
# https://api.data.codeup.com/api/v1/sales?page=135
# https://api.data.codeup.com/api/v1/sales?page=136
# https://api.data.codeup.com/api/v1/sales?page=137
# https://api.data.codeup.com/api/v1/sales?page=138
# https://api.data.codeup.com/api/v1/sales?page=139
# https://api.data.codeup.com/api/v1/sales?page=140
# https://api.data.codeup.com/api/v1/sales?page=141
# https://api.data.codeup.com/api/v1/sales?page=142
# https://api.data.codeup.com/api/v1/sales?page=143
# https://api.data.codeup.com/api/v1/sales?page=144
# https://api.data.codeup.com/api/v1/sales?page=145
# https://api.data.codeup.com/api/v1/sales?page=146
# https://api.data.codeup.com/api/v1/sales?page=147
# https://api.data.codeup.com/api/v1/sales?page=148
# https://api.data.codeup.com/api/v1/sales?page=149
# https://api.data.codeup.com/api/v1/sales?page=150
# https://api.data.codeup.com/api/v1/sales?page=151
# https://api.data.codeup.com/api/v1/sales?page=152
# https://api.data.codeup.com/api/v1/sales?page=153
# https://api.data.codeup.com/api/v1/sales?page=154
# https://api.data.codeup.com/api/v1/sales?page=155
# https://api.data.codeup.com/api/v1/sales?page=156
# https://api.data.codeup.com/api/v1/sales?page=157
# https://api.data.codeup.com/api/v1/sales?page=158
# https://api.data.codeup.com/api/v1/sales?page=159
# https://api.data.codeup.com/api/v1/sales?page=160
# https://api.data.codeup.com/api/v1/sales?page=161
# https://api.data.codeup.com/api/v1/sales?page=162
# https://api.data.codeup.com/api/v1/sales?page=163
# https://api.data.codeup.com/api/v1/sales?page=164
# https://api.data.codeup.com/api/v1/sales?page=165
# https://api.data.codeup.com/api/v1/sales?page=166
# https://api.data.codeup.com/api/v1/sales?page=167
# https://api.data.codeup.com/api/v1/sales?page=168
# https://api.data.codeup.com/api/v1/sales?page=169
# https://api.data.codeup.com/api/v1/sales?page=170
# https://api.data.codeup.com/api/v1/sales?page=171
# https://api.data.codeup.com/api/v1/sales?page=172
# https://api.data.codeup.com/api/v1/sales?page=173
# https://api.data.codeup.com/api/v1/sales?page=174
# https://api.data.codeup.com/api/v1/sales?page=175
# https://api.data.codeup.com/api/v1/sales?page=176
# https://api.data.codeup.com/api/v1/sales?page=177
# https://api.data.codeup.com/api/v1/sales?page=178
# https://api.data.codeup.com/api/v1/sales?page=179
# https://api.data.codeup.com/api/v1/sales?page=180
# https://api.data.codeup.com/api/v1/sales?page=181
# https://api.data.codeup.com/api/v1/sales?page=182
# https://api.data.codeup.com/api/v1/sales?page=183
#         item  sale_amount                      sale_date  sale_id  store
# 0          1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1          1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2          1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3          1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4          1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...      ...          ...                            ...      ...    ...
# 912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
# [913000 rows x 5 columns]

# %%
df = get_data('https://api.data.codeup.com', '/api/v1/items', '?page=', 'payload', 'items', 'max_page')
df
# Out:
# Getting a fresh copy from the api...
# https://api.data.codeup.com/api/v1/items?page=2
# https://api.data.codeup.com/api/v1/items?page=3
#                 item_brand  item_id  \
# 0                 Riceland        1
# 1                   Caress        2
# 2              Earths Best        3
# 3               Boars Head        4
# 4           Back To Nature        5
# 5             Sally Hansen        6
# 6       Twinings Of London        7
# 7            Lea & Perrins        8
# 8             Van De Kamps        9
# 9                    Ahold       10
# 10              Honest Tea       11
# 11                 Mueller       12
# 12   Garnier Nutritioniste       13
# 13                 Pamprin       14
# 14                   Suave       15
# 15              Burts Bees       16
# 16                   Ducal       17
# 17                  Scotch       18
# 18                 Careone       19
# 19            Usda Produce       20
# 20            Doctors Best       21
# 21           Betty Crocker       22
# 22                   Reese       23
# 23            Smart Living       24
# 24                    Hood       25
# 25               Triaminic       26
# 26                  Morton       27
# 27            Usda Produce       28
# 28                   Heinz       29
# 29                 Petmate       30
# 30        Zhenas Gypsy Tea       31
# 31                Barefoot       32
# 32         The First Years       33
# 33                   Halls       34
# 34             Natures Way       35
# 35  Deerfields Gluten Free       36
# 36                  Nakano       37
# 37        Sundown Naturals       38
# 38                Munchies       39
# 39                    Amys       40
# 40             P.f. Changs       41
# 41      Moms Best Naturals       42
# 42                 Ferrara       43
# 43                  Elmers       44
# 44                Kelloggs       45
# 45              Mama Marys       46
# 46              Bear Naked       47
# 47                    Dove       48
# 48                Easy-off       49
# 49                  Choice       50
#
#                                             item_name  item_price  \
# 0                      Riceland American Jazmine Rice        0.84
# 1   Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2   Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 3    Boars Head Sliced White American Cheese - 120 Ct        3.14
# 4   Back To Nature Gluten Free White Cheddar Rice ...        2.61
# 5   Sally Hansen Nail Color Magnetic 903 Silver El...        6.93
# 6   Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 7   Lea & Perrins Marinade In-a-bag Cracked Pepper...        1.68
# 8          Van De Kamps Fillets Beer Battered - 10 Ct        1.79
# 9                                 Ahold Cocoa Almonds        3.17
# 10                         Honest Tea Peach White Tea        3.93
# 11  Mueller Sport Care Basic Support Level Medium ...        8.40
# 12  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 13  Pamprin Maximum Strength Multi-symptom Menstru...        7.54
# 14  Suave Naturals Moisturizing Body Wash Creamy T...        9.11
# 15      Burts Bees Daily Moisturizing Cream Sensitive        5.17
# 16                            Ducal Refried Red Beans        1.16
# 17    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 18                     Careone Family Comb Set - 8 Ct        0.74
# 19                                        Plums Black        5.62
# 20  Doctors Best Best Curcumin C3 Complex 1000mg T...        8.09
# 21  Betty Crocker Twin Pack Real Potatoes Scallope...        7.31
# 22     Reese Mandarin Oranges Segments In Light Syrup        1.78
# 23                Smart Living Charcoal Lighter Fluid        5.34
# 24         Hood Latte Iced Coffee Drink Vanilla Latte        2.43
# 25  Triaminic Syrup Night Time Cold & Cough Grape 4oz        0.98
# 26                          Morton Kosher Salt Coarse        6.01
# 27                                              Guava        7.52
# 28                        Heinz Tomato Ketchup - 2 Ct        8.65
# 29  Petmate Booda Bones Steak Bacon & Chicken Flav...        8.39
# 30  Zhenas Gypsy Tea Herbal Red Tea Sachets Fire L...        4.21
# 31                         Barefoot Pinot Grigio  187        0.68
# 32  Tomy The First Years Gumdrop Orthodontic Pacif...        6.52
# 33  Halls Menthol Cough Suppresant/oral Anesthetic...        4.17
# 34                     Natures Way Forskohlii - 60 Ct        5.19
# 35           Rice Bran Gluten Free Dinner Rolls Plain        7.95
# 36              Nakano Seasoned Rice Vinegar Original        9.59
# 37  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 38  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 39               Amys Light & Lean Spaghetti Italiano        0.60
# 40  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 41  Moms Best Naturals Cereal Toasted Cinnamon Squ...        2.97
# 42                              Ferrara Vanilla Syrup        8.40
# 43                Elmers Board Mate Dual Tip Glue Pen        7.06
# 44                Kelloggs Disney Pixar Cars 2 Cereal        4.40
# 45                                        Pizza Sauce        4.65
# 46  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# 47  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 48                  Easy-off Oven Cleaner Lemon Scent        9.54
# 49  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#       item_upc12    item_upc14
# 0    35200264013   35200264013
# 1    11111065925   11111065925
# 2    23923330139   23923330139
# 3   208528800007  208528800007
# 4   759283100036  759283100036
# 5    74170388732   74170388732
# 6    70177154004   70177154004
# 7    51600080015   51600080015
# 8    19600923015   19600923015
# 9   688267141676  688267141676
# 10  657622604842  657622604842
# 11   74676640211   74676640211
# 12  603084234561  603084234561
# 13   41167300121   41167300121
# 14   79400847201   79400847201
# 15  792850014008  792850014008
# 16   88313590791   88313590791
# 17   21200725340   21200725340
# 18   41520035646   41520035646
# 19  204040000000  204040000000
# 20  753950001954  753950001954
# 21   16000288829   16000288829
# 22   70670009658   70670009658
# 23  688267084225  688267084225
# 24   44100117428   44100117428
# 25  300436344045  300436344045
# 26   24600017008   24600017008
# 27  719175900007  719175900007
# 28   13000001038   13000001038
# 29  723503568678  723503568678
# 30  652790100226  652790100226
# 31    8500004528    8500004528
# 32   71463060078   71463060078
# 33  312546628694  312546628694
# 34   33674100066   33674100066
# 35  610358991525  610358991525
# 36   73575295003   73575295003
# 37   30768540548   30768540548
# 38   28400029254   28400029254
# 39   42272008063   42272008063
# 40   31000670016   31000670016
# 41  883978129115  883978129115
# 42   71403000379   71403000379
# 43   26000001403   26000001403
# 44   38000542237   38000542237
# 45   35457770664   35457770664
# 46  884623708976  884623708976
# 47   79400271631   79400271631
# 48   62338879772   62338879772
# 49   47445919221   47445919221

# %%
from acquire import stores_items_sales_data

# %%
df = stores_items_sales_data()
# Out:
# Getting a fresh copy from the api...
# Getting a fresh copy from the api...
# https://api.data.codeup.com/api/v1/items?page=2
# https://api.data.codeup.com/api/v1/items?page=3
# Getting a fresh copy from the api...
# https://api.data.codeup.com/api/v1/sales?page=2
# https://api.data.codeup.com/api/v1/sales?page=3
# https://api.data.codeup.com/api/v1/sales?page=4
# https://api.data.codeup.com/api/v1/sales?page=5
# https://api.data.codeup.com/api/v1/sales?page=6
# https://api.data.codeup.com/api/v1/sales?page=7
# https://api.data.codeup.com/api/v1/sales?page=8
# https://api.data.codeup.com/api/v1/sales?page=9
# https://api.data.codeup.com/api/v1/sales?page=10
# https://api.data.codeup.com/api/v1/sales?page=11
# https://api.data.codeup.com/api/v1/sales?page=12
# https://api.data.codeup.com/api/v1/sales?page=13
# https://api.data.codeup.com/api/v1/sales?page=14
# https://api.data.codeup.com/api/v1/sales?page=15
# https://api.data.codeup.com/api/v1/sales?page=16
# https://api.data.codeup.com/api/v1/sales?page=17
# https://api.data.codeup.com/api/v1/sales?page=18
# https://api.data.codeup.com/api/v1/sales?page=19
# https://api.data.codeup.com/api/v1/sales?page=20
# https://api.data.codeup.com/api/v1/sales?page=21
# https://api.data.codeup.com/api/v1/sales?page=22
# https://api.data.codeup.com/api/v1/sales?page=23
# https://api.data.codeup.com/api/v1/sales?page=24
# https://api.data.codeup.com/api/v1/sales?page=25
# https://api.data.codeup.com/api/v1/sales?page=26
# https://api.data.codeup.com/api/v1/sales?page=27
# https://api.data.codeup.com/api/v1/sales?page=28
# https://api.data.codeup.com/api/v1/sales?page=29
# https://api.data.codeup.com/api/v1/sales?page=30
# https://api.data.codeup.com/api/v1/sales?page=31
# https://api.data.codeup.com/api/v1/sales?page=32
# https://api.data.codeup.com/api/v1/sales?page=33
# https://api.data.codeup.com/api/v1/sales?page=34
# https://api.data.codeup.com/api/v1/sales?page=35
# https://api.data.codeup.com/api/v1/sales?page=36
# https://api.data.codeup.com/api/v1/sales?page=37
# https://api.data.codeup.com/api/v1/sales?page=38
# https://api.data.codeup.com/api/v1/sales?page=39
# https://api.data.codeup.com/api/v1/sales?page=40
# https://api.data.codeup.com/api/v1/sales?page=41
# https://api.data.codeup.com/api/v1/sales?page=42
# https://api.data.codeup.com/api/v1/sales?page=43
# https://api.data.codeup.com/api/v1/sales?page=44
# https://api.data.codeup.com/api/v1/sales?page=45
# https://api.data.codeup.com/api/v1/sales?page=46
# https://api.data.codeup.com/api/v1/sales?page=47
# https://api.data.codeup.com/api/v1/sales?page=48
# https://api.data.codeup.com/api/v1/sales?page=49
# https://api.data.codeup.com/api/v1/sales?page=50
# https://api.data.codeup.com/api/v1/sales?page=51
# https://api.data.codeup.com/api/v1/sales?page=52
# https://api.data.codeup.com/api/v1/sales?page=53
# https://api.data.codeup.com/api/v1/sales?page=54
# https://api.data.codeup.com/api/v1/sales?page=55
# https://api.data.codeup.com/api/v1/sales?page=56
# https://api.data.codeup.com/api/v1/sales?page=57
# https://api.data.codeup.com/api/v1/sales?page=58
# https://api.data.codeup.com/api/v1/sales?page=59
# https://api.data.codeup.com/api/v1/sales?page=60
# https://api.data.codeup.com/api/v1/sales?page=61
# https://api.data.codeup.com/api/v1/sales?page=62
# https://api.data.codeup.com/api/v1/sales?page=63
# https://api.data.codeup.com/api/v1/sales?page=64
# https://api.data.codeup.com/api/v1/sales?page=65
# https://api.data.codeup.com/api/v1/sales?page=66
# https://api.data.codeup.com/api/v1/sales?page=67
# https://api.data.codeup.com/api/v1/sales?page=68
# https://api.data.codeup.com/api/v1/sales?page=69
# https://api.data.codeup.com/api/v1/sales?page=70
# https://api.data.codeup.com/api/v1/sales?page=71
# https://api.data.codeup.com/api/v1/sales?page=72
# https://api.data.codeup.com/api/v1/sales?page=73
# https://api.data.codeup.com/api/v1/sales?page=74
# https://api.data.codeup.com/api/v1/sales?page=75
# https://api.data.codeup.com/api/v1/sales?page=76
# https://api.data.codeup.com/api/v1/sales?page=77
# https://api.data.codeup.com/api/v1/sales?page=78
# https://api.data.codeup.com/api/v1/sales?page=79
# https://api.data.codeup.com/api/v1/sales?page=80
# https://api.data.codeup.com/api/v1/sales?page=81
# https://api.data.codeup.com/api/v1/sales?page=82
# https://api.data.codeup.com/api/v1/sales?page=83
# https://api.data.codeup.com/api/v1/sales?page=84
# https://api.data.codeup.com/api/v1/sales?page=85
# https://api.data.codeup.com/api/v1/sales?page=86
# https://api.data.codeup.com/api/v1/sales?page=87
# https://api.data.codeup.com/api/v1/sales?page=88
# https://api.data.codeup.com/api/v1/sales?page=89
# https://api.data.codeup.com/api/v1/sales?page=90
# https://api.data.codeup.com/api/v1/sales?page=91
# https://api.data.codeup.com/api/v1/sales?page=92
# https://api.data.codeup.com/api/v1/sales?page=93
# https://api.data.codeup.com/api/v1/sales?page=94
# https://api.data.codeup.com/api/v1/sales?page=95
# https://api.data.codeup.com/api/v1/sales?page=96
# https://api.data.codeup.com/api/v1/sales?page=97
# https://api.data.codeup.com/api/v1/sales?page=98
# https://api.data.codeup.com/api/v1/sales?page=99
# https://api.data.codeup.com/api/v1/sales?page=100
# https://api.data.codeup.com/api/v1/sales?page=101
# https://api.data.codeup.com/api/v1/sales?page=102
# https://api.data.codeup.com/api/v1/sales?page=103
# https://api.data.codeup.com/api/v1/sales?page=104
# https://api.data.codeup.com/api/v1/sales?page=105
# https://api.data.codeup.com/api/v1/sales?page=106
# https://api.data.codeup.com/api/v1/sales?page=107
# https://api.data.codeup.com/api/v1/sales?page=108
# https://api.data.codeup.com/api/v1/sales?page=109
# https://api.data.codeup.com/api/v1/sales?page=110
# https://api.data.codeup.com/api/v1/sales?page=111
# https://api.data.codeup.com/api/v1/sales?page=112
# https://api.data.codeup.com/api/v1/sales?page=113
# https://api.data.codeup.com/api/v1/sales?page=114
# https://api.data.codeup.com/api/v1/sales?page=115
# https://api.data.codeup.com/api/v1/sales?page=116
# https://api.data.codeup.com/api/v1/sales?page=117
# https://api.data.codeup.com/api/v1/sales?page=118
# https://api.data.codeup.com/api/v1/sales?page=119
# https://api.data.codeup.com/api/v1/sales?page=120
# https://api.data.codeup.com/api/v1/sales?page=121
# https://api.data.codeup.com/api/v1/sales?page=122
# https://api.data.codeup.com/api/v1/sales?page=123
# https://api.data.codeup.com/api/v1/sales?page=124
# https://api.data.codeup.com/api/v1/sales?page=125
# https://api.data.codeup.com/api/v1/sales?page=126
# https://api.data.codeup.com/api/v1/sales?page=127
# https://api.data.codeup.com/api/v1/sales?page=128
# https://api.data.codeup.com/api/v1/sales?page=129
# https://api.data.codeup.com/api/v1/sales?page=130
# https://api.data.codeup.com/api/v1/sales?page=131
# https://api.data.codeup.com/api/v1/sales?page=132
# https://api.data.codeup.com/api/v1/sales?page=133
# https://api.data.codeup.com/api/v1/sales?page=134
# https://api.data.codeup.com/api/v1/sales?page=135
# https://api.data.codeup.com/api/v1/sales?page=136
# https://api.data.codeup.com/api/v1/sales?page=137
# https://api.data.codeup.com/api/v1/sales?page=138
# https://api.data.codeup.com/api/v1/sales?page=139
# https://api.data.codeup.com/api/v1/sales?page=140
# https://api.data.codeup.com/api/v1/sales?page=141
# https://api.data.codeup.com/api/v1/sales?page=142
# https://api.data.codeup.com/api/v1/sales?page=143
# https://api.data.codeup.com/api/v1/sales?page=144
# https://api.data.codeup.com/api/v1/sales?page=145
# https://api.data.codeup.com/api/v1/sales?page=146
# https://api.data.codeup.com/api/v1/sales?page=147
# https://api.data.codeup.com/api/v1/sales?page=148
# https://api.data.codeup.com/api/v1/sales?page=149
# https://api.data.codeup.com/api/v1/sales?page=150
# https://api.data.codeup.com/api/v1/sales?page=151
# https://api.data.codeup.com/api/v1/sales?page=152
# https://api.data.codeup.com/api/v1/sales?page=153
# https://api.data.codeup.com/api/v1/sales?page=154
# https://api.data.codeup.com/api/v1/sales?page=155
# https://api.data.codeup.com/api/v1/sales?page=156
# https://api.data.codeup.com/api/v1/sales?page=157
# https://api.data.codeup.com/api/v1/sales?page=158
# https://api.data.codeup.com/api/v1/sales?page=159
# https://api.data.codeup.com/api/v1/sales?page=160
# https://api.data.codeup.com/api/v1/sales?page=161
# https://api.data.codeup.com/api/v1/sales?page=162
# https://api.data.codeup.com/api/v1/sales?page=163
# https://api.data.codeup.com/api/v1/sales?page=164
# https://api.data.codeup.com/api/v1/sales?page=165
# https://api.data.codeup.com/api/v1/sales?page=166
# https://api.data.codeup.com/api/v1/sales?page=167
# https://api.data.codeup.com/api/v1/sales?page=168
# https://api.data.codeup.com/api/v1/sales?page=169
# https://api.data.codeup.com/api/v1/sales?page=170
# https://api.data.codeup.com/api/v1/sales?page=171
# https://api.data.codeup.com/api/v1/sales?page=172
# https://api.data.codeup.com/api/v1/sales?page=173
# https://api.data.codeup.com/api/v1/sales?page=174
# https://api.data.codeup.com/api/v1/sales?page=175
# https://api.data.codeup.com/api/v1/sales?page=176
# https://api.data.codeup.com/api/v1/sales?page=177
# https://api.data.codeup.com/api/v1/sales?page=178
# https://api.data.codeup.com/api/v1/sales?page=179
# https://api.data.codeup.com/api/v1/sales?page=180
# https://api.data.codeup.com/api/v1/sales?page=181
# https://api.data.codeup.com/api/v1/sales?page=182
# https://api.data.codeup.com/api/v1/sales?page=183

# %%
df.head()
# Out:
#    item_id  sale_amount                      sale_date  sale_id  store_id  \
# 0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1         1
# 1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2         1
# 2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3         1
# 3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4         1
# 4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5         1
#
#   item_brand                       item_name  item_price   item_upc12  \
# 0   Riceland  Riceland American Jazmine Rice        0.84  35200264013
# 1   Riceland  Riceland American Jazmine Rice        0.84  35200264013
# 2   Riceland  Riceland American Jazmine Rice        0.84  35200264013
# 3   Riceland  Riceland American Jazmine Rice        0.84  35200264013
# 4   Riceland  Riceland American Jazmine Rice        0.84  35200264013
#
#     item_upc14           store_address   store_city store_state store_zipcode
# 0  35200264013  12125 Alamo Ranch Pkwy  San Antonio          TX         78253
# 1  35200264013  12125 Alamo Ranch Pkwy  San Antonio          TX         78253
# 2  35200264013  12125 Alamo Ranch Pkwy  San Antonio          TX         78253
# 3  35200264013  12125 Alamo Ranch Pkwy  San Antonio          TX         78253
# 4  35200264013  12125 Alamo Ranch Pkwy  San Antonio          TX         78253

# %%
df.shape
# Out:
# (913000, 14)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')

# %%
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
df = get_opsd()
# Out:
# Getting a fresh copy of the data

# %%
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN
